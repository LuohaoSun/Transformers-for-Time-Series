# %%
import sys
sys.path.append("..")

import pandas as pd

# %%
df = pd.read_hdf("../data/ca_2021_15min_resample/ca_his_2021.h5")
print(df.describe())
# Out:
#              317802        312134        312133        313159        319767  \
# count  35040.000000  35040.000000  35040.000000  35040.000000  35040.000000
# mean     120.155879    105.813413    134.602026    164.339583    150.351427
# std       55.069699     58.517038     75.168112     87.225515     83.669255
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       75.000000     56.000000     59.000000     78.000000     66.000000
# 50%      107.000000    103.000000    148.000000    178.000000    165.000000
# 75%      164.000000    147.000000    194.000000    236.000000    219.000000
# max      333.000000    357.000000    370.000000    400.000000    366.000000
#
#              319780        317830        314876        314886        314909  \
# count  35040.000000  35040.000000  35040.000000  35040.000000  35040.000000
# mean     208.290411    127.568750    158.205622    172.784189    228.699772
# ...

# %%
print(df.isnull().sum().sum())
# Out:
# 0

# %%
import numpy as np

print(df.iloc[109])
# Out:
# 317802     55.0
# 312134     35.0
# 312133     24.0
# 313159     18.0
# 319767     17.0
#            ...
# 1202527    10.0
# 1202549     9.0
# 1219560    39.0
# 1202522    17.0
# 1202537    16.0
# Name: 2021-01-02 03:15:00, Length: 8600, dtype: float64

# %%
ndarray = df.to_numpy()
print(ndarray.shape)
print(ndarray[0,109])
# Out:
# (35040, 8600)
# 0.0

# %%
print(np.isnan(ndarray).sum())
# Out:
# 0
